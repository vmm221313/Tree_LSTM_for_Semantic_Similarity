# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import pandas as po

# %% [markdown]
# ## Best Score
# Pearson = 0.8621
# mem_dim = 100
# hidden_dim = 200
# lr = 0.03
# wd = 0.001
# epochs = 10
# seed = 1947

# %%
# !python treelstm/main.py --lr 0.000001 --wd 0.001 --optim adagrad --batchsize 1000  --seed 1947 --epochs 1 --hidden_dim 200 --mem_dim 100 --model alldep
# Out:
# [2019-12-10 16:06:55,680] DEBUG:__main__:Namespace(batchsize=1000, cuda=False, data='data/sick/', epochs=1, evaluate=False, expname='test', freeze_embed=True, glove='data/glove/', hidden_dim=200, input_dim=300, load_model=False, lr=1e-06, mem_dim=100, model_type='alldep', num_classes=5, optim='adagrad', save='checkpoints/', saved_model=None, seed=1947, sparse=False, wd=0.001)
# [2019-12-10 16:06:55,682] DEBUG:__main__:==> SICK vocabulary size : 2412
# [2019-12-10 16:06:55,682] DEBUG:__main__:==> RELATION vocabulary size : 37
# [2019-12-10 16:06:56,166] DEBUG:__main__:==> Size of train data   : 4500
# [2019-12-10 16:06:56,194] DEBUG:__main__:==> Size of dev data     : 500
# [2019-12-10 16:06:56,864] DEBUG:__main__:==> Size of test data     : 4927
# ...

# %%
# !python treelstm/main.py --lr 0.1 --wd 0.0001 --optim adam --batchsize 25  --seed 1947 --epochs 1 --hidden_dim 200 --mem_dim 100 --model mdep --load_model --saved_model "mdep/2019-12-10-11-8_300_100_200_adam_10.0_0.0001_25_mdep" --evaluate
# Out:
# [2019-12-10 11:23:46,008] DEBUG:__main__:Namespace(batchsize=25, cuda=False, data='data/sick/', epochs=1, evaluate=True, expname='test', freeze_embed=True, glove='data/glove/', hidden_dim=200, input_dim=300, load_model=True, lr=0.1, mem_dim=100, model_type='mdep', num_classes=5, optim='adam', save='checkpoints/', saved_model='mdep/2019-12-10-11-8_300_100_200_adam_10.0_0.0001_25_mdep', seed=1947, sparse=False, wd=0.0001)
# [2019-12-10 11:23:46,011] DEBUG:__main__:==> SICK vocabulary size : 2412
# [2019-12-10 11:23:46,011] DEBUG:__main__:==> RELATION vocabulary size : 37
# [2019-12-10 11:23:46,472] DEBUG:__main__:==> Size of train data   : 4500
# [2019-12-10 11:23:46,499] DEBUG:__main__:==> Size of dev data     : 500
# [2019-12-10 11:23:47,343] DEBUG:__main__:==> Size of test data     : 4927
# 1
# ...

# %% [markdown]
# --load_model --saved_model "mdep/2019-12-10-11-8_300_100_200_adam_10.0_0.0001_25_mdep.pt"

# %%
# !python treelstm/main.py --lr 0.03 --wd 0.001 --optim adam --batchsize 25  --seed 1947 --epochs 1 --hidden_dim 200 --mem_dim 100 --model alldep
# Out:
# [2019-12-10 12:10:00,470] DEBUG:__main__:Namespace(batchsize=25, cuda=False, data='data/sick/', epochs=1, evaluate=False, expname='test', freeze_embed=True, glove='data/glove/', hidden_dim=200, input_dim=300, load_model=False, lr=0.03, mem_dim=100, model_type='alldep', num_classes=5, optim='adam', save='checkpoints/', saved_model=None, seed=1947, sparse=False, wd=0.001)
# [2019-12-10 12:10:00,472] DEBUG:__main__:==> SICK vocabulary size : 2412
# [2019-12-10 12:10:00,473] DEBUG:__main__:==> RELATION vocabulary size : 37
# [2019-12-10 12:10:00,958] DEBUG:__main__:==> Size of train data   : 4500
# [2019-12-10 12:10:00,997] DEBUG:__main__:==> Size of dev data     : 500
# [2019-12-10 12:10:01,810] DEBUG:__main__:==> Size of test data     : 4927
# ...

# %%
# !python treelstm/main.py --lr 0.000001 --wd 0.001 --optim adam --batchsize 25  --seed 1947 --epochs 1 --hidden_dim 200 --mem_dim 100 --model mdep
# Out:
# [2019-12-10 14:05:36,773] DEBUG:__main__:Namespace(batchsize=25, cuda=False, data='data/sick/', epochs=1, evaluate=False, expname='test', freeze_embed=True, glove='data/glove/', hidden_dim=200, input_dim=300, load_model=False, lr=1e-06, mem_dim=100, model_type='mdep', num_classes=5, optim='adam', save='checkpoints/', saved_model=None, seed=1947, sparse=False, wd=0.001)
# [2019-12-10 14:05:36,775] DEBUG:__main__:==> SICK vocabulary size : 2412
# [2019-12-10 14:05:36,776] DEBUG:__main__:==> RELATION vocabulary size : 37
# [2019-12-10 14:05:37,274] DEBUG:__main__:==> Size of train data   : 4500
# [2019-12-10 14:05:37,303] DEBUG:__main__:==> Size of dev data     : 500
# [2019-12-10 14:05:38,045] DEBUG:__main__:==> Size of test data     : 4927
# ...
